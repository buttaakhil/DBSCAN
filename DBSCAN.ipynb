# %% [markdown]
# <a href="https://colab.research.google.com/github/buttaakhil/DBSCAN/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=250, noise=0.05)

# %%
df={"data1":x[:,0],"data2":x[:,1],"output":y}

# %%
dataset=pd.DataFrame(df)
print(dataset.head(3))
# Out:
#       data1     data2  output
# 0 -0.493621  0.925561       0
# 1  0.163062  1.038714       0
# 2 -0.734563  0.535363       0

# %%
sns.scatterplot(x="data1",y="data2",data=dataset,hue="output")
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=1,min_samples=5)
dataset["Predict"]=db.fit_predict(dataset)

# %%
sns.scatterplot(x="data1",y="data2",data=dataset,hue="Predict")
plt.show()
